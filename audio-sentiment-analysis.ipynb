# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from util import load_data, extract_feature, split_data, get_result
from lstm_model import lstm_model

# %% [markdown]
# ## Train LSTM

# %%
# load the dataset
X, y = load_data()

# split the data into training, validation and testing sets
data = split_data(X, y, test_size=0.2, valid_size=0.2)

y_train = data["y_train"].reshape(-1).astype(int)
y_valid = data["y_valid"].reshape(-1).astype(int)
y_test = data["y_test"].reshape(-1).astype(int)
time_steps = data["time_steps"]
num_features = data["n_features"]
num_samples = data["n_samples"]

# construct the model
model = lstm_model(time_steps, num_features)

# use tensorboard to view metrics
tensorboard = TensorBoard(log_dir="logs")
# define early stopping to stop training after 5 epochs of not improving
early_stopping = EarlyStopping(mode="min", patience=5, restore_best_weights=True)

batch_size = 32
epochs = 200

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=0.00001)

# train the model using the training set and validating using validation set
history = model.fit(data["X_train"], y_train, epochs=epochs, batch_size=batch_size, validation_data=(data["X_valid"], y_valid),
          callbacks=[tensorboard, early_stopping])

# save the model to a file
model.save("results/model.h5")

# evaluating the model using the testing set
print(f"Evaluating the model using {len(data['X_test'])} samples...")
loss, accuracy = model.evaluate(data["X_test"], y_test, verbose=0)
print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")
# Out:
# Total neutral samples: 81
# Total positive samples: 97
# Total negative samples: 102
# Loading data: 100%|██████████████████████████████████████████████████████████████████| 280/280 [00:06<00:00, 46.65it/s]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 1, 512)           788480
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 256)              656384
#  nal)
#
#  dense (Dense)               (None, 64)                16448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 1,467,651
# Trainable params: 1,467,651
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 6/6 [==============================] - 10s 406ms/step - loss: 1.0726 - accuracy: 0.4022 - val_loss: 1.0117 - val_accuracy: 0.5111
# Epoch 2/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.9262 - accuracy: 0.5140 - val_loss: 0.8130 - val_accuracy: 0.5333
# Epoch 3/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.7987 - accuracy: 0.5419 - val_loss: 0.7056 - val_accuracy: 0.5556
# Epoch 4/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.7128 - accuracy: 0.5419 - val_loss: 0.6372 - val_accuracy: 0.6444
# Epoch 5/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.6455 - accuracy: 0.6480 - val_loss: 0.5864 - val_accuracy: 0.6889
# Epoch 6/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.6185 - accuracy: 0.6536 - val_loss: 0.5247 - val_accuracy: 0.6889
# Epoch 7/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.5685 - accuracy: 0.6313 - val_loss: 0.5018 - val_accuracy: 0.6667
# Epoch 8/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.5169 - accuracy: 0.6816 - val_loss: 0.4378 - val_accuracy: 0.7778
# Epoch 9/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4952 - accuracy: 0.7263 - val_loss: 0.4773 - val_accuracy: 0.7111
# Epoch 10/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.5031 - accuracy: 0.7039 - val_loss: 0.3283 - val_accuracy: 0.9333
# Epoch 11/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3986 - accuracy: 0.8380 - val_loss: 0.2975 - val_accuracy: 0.8667
# Epoch 12/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3914 - accuracy: 0.8212 - val_loss: 0.6386 - val_accuracy: 0.6667
# Epoch 13/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4387 - accuracy: 0.7821 - val_loss: 0.3133 - val_accuracy: 0.8444
# Epoch 14/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3435 - accuracy: 0.8380 - val_loss: 0.2136 - val_accuracy: 0.9333
# Epoch 15/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3582 - accuracy: 0.8492 - val_loss: 0.1889 - val_accuracy: 0.9333
# Epoch 16/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3329 - accuracy: 0.8212 - val_loss: 0.2998 - val_accuracy: 0.8222
# Epoch 17/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2836 - accuracy: 0.8883 - val_loss: 0.1703 - val_accuracy: 0.9333
# Epoch 18/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2148 - accuracy: 0.9441 - val_loss: 0.1156 - val_accuracy: 0.9778
# Epoch 19/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.3229 - accuracy: 0.8659 - val_loss: 0.4081 - val_accuracy: 0.8222
# Epoch 20/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2624 - accuracy: 0.9218 - val_loss: 0.1122 - val_accuracy: 0.9556
# Epoch 21/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2365 - accuracy: 0.8994 - val_loss: 0.3404 - val_accuracy: 0.8222
# Epoch 22/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2991 - accuracy: 0.8827 - val_loss: 0.1016 - val_accuracy: 0.9556
# Epoch 23/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2501 - accuracy: 0.9106 - val_loss: 0.2974 - val_accuracy: 0.8444
# Epoch 24/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1989 - accuracy: 0.9218 - val_loss: 0.0804 - val_accuracy: 0.9778
# Epoch 25/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.1792 - accuracy: 0.9385 - val_loss: 0.2481 - val_accuracy: 0.9333
# Epoch 26/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2211 - accuracy: 0.9218 - val_loss: 0.1486 - val_accuracy: 0.9556
# Epoch 27/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1503 - accuracy: 0.9553 - val_loss: 0.0787 - val_accuracy: 0.9556
# Epoch 28/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2162 - accuracy: 0.9274 - val_loss: 0.0329 - val_accuracy: 1.0000
# Epoch 29/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.1359 - accuracy: 0.9497 - val_loss: 0.6509 - val_accuracy: 0.7778
# Epoch 30/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3064 - accuracy: 0.9162 - val_loss: 0.1326 - val_accuracy: 0.9333
# Epoch 31/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.0848 - accuracy: 0.9888 - val_loss: 0.0665 - val_accuracy: 0.9556
# Epoch 32/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0867 - accuracy: 0.9777 - val_loss: 0.1768 - val_accuracy: 0.9333
# Epoch 33/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1032 - accuracy: 0.9721 - val_loss: 0.0476 - val_accuracy: 0.9778
# Evaluating the model using 56 samples...
# Loss: 0.1755
# Accuracy: 92.86%

# %% [markdown]
# ## Test LSTM

# %%
feat = extract_feature("datasets/all/24.wav", mfcc=True)
feat = np.expand_dims(feat, axis=0)  # Add an extra dimension at the beginning
feat = np.expand_dims(feat, axis=1)

prediction = model.predict(feat)

predicted_class = np.argmax(prediction)

print(prediction)
get_result(predicted_class)
# Out:
# 1/1 [==============================] - 2s 2s/step
# [[3.1843025e-02 6.3373212e-05 9.6809351e-01]]
# ['positive']

# %%
feat = extract_feature("datasets/all/h01.wav", mfcc=True)
feat = np.expand_dims(feat, axis=0)  # Add an extra dimension at the beginning
feat = np.expand_dims(feat, axis=1)

prediction = model.predict(feat)

predicted_class = np.argmax(prediction)

print(prediction)
get_result(predicted_class)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# [[1.19348075e-02 7.22623190e-06 9.88057971e-01]]
# ['positive']

# %%
feat = extract_feature("datasets/all/d01.wav", mfcc=True)
feat = np.expand_dims(feat, axis=0)  # Add an extra dimension at the beginning
feat = np.expand_dims(feat, axis=1)

prediction = model.predict(feat)

predicted_class = np.argmax(prediction)

print(prediction)
get_result(predicted_class)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# [[9.9783915e-01 8.4342707e-07 2.1600383e-03]]
# ['negative']

# %%
feat = extract_feature("datasets/all/d15.wav", mfcc=True)
feat = np.expand_dims(feat, axis=0)  # Add an extra dimension at the beginning
feat = np.expand_dims(feat, axis=1)

prediction = model.predict(feat)

predicted_class = np.argmax(prediction)

print(prediction)
get_result(predicted_class)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# [[9.9849200e-01 6.8331593e-07 1.5072760e-03]]
# ['negative']

# %% [markdown]
# ## Learning Stats for LSTM

# %%
# Extract the values of the metrics from the history
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Plot the learning curve for loss
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Learning Curve - Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot the learning curve for accuracy
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Learning Curve - Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
